# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
data = pd.read_json("../Data/Historical_data.json")

data.head(1)
# Out:
#        id  quiz_id                       user_id  \
# 0  336497       51  YcDFSO4ZukTJnnFMgRNVwZTE4j42
#
#                       submitted_at                       created_at  \
# 0 2025-01-17 15:30:18.027000+05:30 2025-01-17 15:30:18.044000+05:30
#
#                         updated_at  score  trophy_level accuracy  speed  ...  \
# 0 2025-01-17 15:30:18.044000+05:30    108             2     90 %    100  ...
#
#                  started_at                  ended_at  duration  better_than  \
# 0 2025-01-17 15:18:30+05:30 2025-01-17 15:30:15+05:30     15:00          107
#
#   total_questions           rank_text mistakes_corrected  \
# 0             100  Topic Rank - #-171                  9
#
#   initial_mistake_count                                       response_map  \
# 0                    12  {'2523': 10109, '2529': 10130, '2533': 10149, ...
#
#                                                 quiz
# 0  {'id': 51, 'name': None, 'title': 'Human Physi...
#
# [1 rows x 26 columns]

# %% [markdown]
# # Key Features To Consider
# 1. quiz_id
# 2. score
# 3. trophy level
# 4. accuracy
# 5. final_score
# 6. duration
# 7. better_than
# 8. initial_mistake_count
# 9. title
# 10. topic

# %%
def topic(x):
    return str(x["topic"]).lower()


def title(x):
    return str(x["title"]).lower()

# %%
data["topic"] = data["quiz"].apply(topic)
data["title"] = data["quiz"].apply(title)

# %%
data = data[
    [
        "quiz_id",
        "score",
        "trophy_level",
        "accuracy",
        "final_score",
        "started_at",
        "ended_at",
        "duration",
        "better_than",
        "initial_mistake_count",
        "title",
        "topic",
    ]
]

# %%
def total_time(x):
    return (
        datetime.fromisoformat(str(x["ended_at"]))
        - datetime.fromisoformat(str(x["started_at"]))
    ).total_seconds() / 60

# %%
data["time_taken"] = data.apply(total_time, axis=1)
data = data.drop(["started_at", "ended_at"], axis=1)
data.head()
# Out:
#    quiz_id  score  trophy_level accuracy  final_score duration  better_than  \
# 0       51    108             2     90 %          105    15:00          107
# 1        6     92             1    100 %           92    15:00          395
# 2       51    116             2     96 %          115    15:00          115
# 3        6     36             2     90 %           35    15:00          152
# 4       51     36             3     31 %           16    15:00           35
#
#    initial_mistake_count                  title                         topic  \
# 0                     12  human physiology (15)   body fluids and circulation
# 1                      3   human physiology pyq  body fluids and circulation
# 2                     12  human physiology (15)   body fluids and circulation
# 3                      2   human physiology pyq  body fluids and circulation
# 4                     20  human physiology (15)   body fluids and circulation
#
#    time_taken
# 0   11.750000
# ...

# %%
def accuracy(x):
    return int(x["accuracy"].split(" %")[0])


def duration(x):
    return int(x["duration"].split(":")[0])

# %%
data["accuracy"] = data.apply(accuracy, axis=1)
data["duration"] = data.apply(duration, axis=1)

# %%
data_new = data.groupby("quiz_id")
data_new.first()
# Out:
#          score  trophy_level  accuracy  final_score  duration  better_than  \
# quiz_id
# 6           92             1       100           92        15          395
# 18          40             1       100           40        15          177
# 20          12             2        30            5        15           18
# 24          76             2       100           76        15          375
# 25         112             2        93          110        15          270
# 50          24             3        66           21        15           23
# 51         108             2        90          105        15          107
# 57          40             3        38           24        15           43
# 58          52             2        43           35        15           92
#
#          initial_mistake_count                                        title  \
# quiz_id
# 6                            3                         human physiology pyq
# ...

# %%
data_vis = data.groupby(["quiz_id"]).aggregate(
    avg_score=("score", "mean"),
    avg_accuracy=("accuracy", "mean"),
    avg_time=("time_taken", "mean"),
    avg_initial_mistake_count=("initial_mistake_count", "mean"),
)
data_vis
# Out:
#           avg_score  avg_accuracy   avg_time  avg_initial_mistake_count
# quiz_id
# 6         54.666667     80.000000  10.061111                   4.666667
# 18        52.000000     92.000000   3.508333                   1.500000
# 20        12.000000     30.000000   4.583333                   7.000000
# 24        76.000000    100.000000  13.900000                   4.000000
# 25       112.000000     93.000000  15.750000                  14.000000
# 50        24.000000     66.000000   5.466667                   3.000000
# 51        86.666667     72.333333  12.366667                  14.666667
# 57        40.000000     38.000000  10.100000                  16.000000
# 58        52.000000     43.000000  16.383333                  17.000000

# %%
data_vis.to_csv("../Data/data_visualize.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Plot avg_score for different quiz_id
plt.figure(figsize=(10, 6))
sns.barplot(x=data_vis.index, y=data_vis["avg_score"], palette="viridis")
plt.title("Average Score by Quiz ID")
plt.xlabel("Quiz ID")
plt.ylabel("Average Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot avg_accuracy for different quiz_id
plt.figure(figsize=(10, 6))
sns.barplot(x=data_vis.index, y=data_vis["avg_accuracy"], palette="muted")
plt.title("Average Accuracy by Quiz ID")
plt.xlabel("Quiz ID")
plt.ylabel("Average Accuracy")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot avg_time for different quiz_id
plt.figure(figsize=(10, 6))
sns.barplot(x=data_vis.index, y=data_vis["avg_time"], palette="coolwarm")
plt.title("Average Time Taken by Quiz ID")
plt.xlabel("Quiz ID")
plt.ylabel("Average Time (minutes)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot avg_initial_mistake_count for different quiz_id
plt.figure(figsize=(10, 6))
sns.barplot(x=data_vis.index, y=data_vis["avg_initial_mistake_count"], palette="pastel")
plt.title("Average Initial Mistake Count by Quiz ID")
plt.xlabel("Quiz ID")
plt.ylabel("Average Initial Mistake Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9w/csn11pg56mz_mqtbmcxzdc340000gn/T/ipykernel_82976/2065277101.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_vis.index, y=data_vis["avg_score"], palette="viridis")
# /var/folders/9w/csn11pg56mz_mqtbmcxzdc340000gn/T/ipykernel_82976/2065277101.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_vis.index, y=data_vis["avg_accuracy"], palette="muted")
# /var/folders/9w/csn11pg56mz_mqtbmcxzdc340000gn/T/ipykernel_82976/2065277101.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
data["combined"] = (
    data["trophy_level"].astype(str)
    + " "
    + data["accuracy"].astype(str)
    + " "
    + data["final_score"].astype(str)
    + " "
    + data["duration"].astype(str)
    + " "
    + data["better_than"].astype(str)
    + " "
    + data["initial_mistake_count"].astype(str)
    + " "
    + data["title"].astype(str)
)

# %%
data.head(2)
# Out:
#    quiz_id  score  trophy_level  accuracy  final_score  duration  better_than  \
# 0       51    108             2        90          105        15          107
# 1        6     92             1       100           92        15          395
#
#    initial_mistake_count                  title                         topic  \
# 0                     12  human physiology (15)   body fluids and circulation
# 1                      3   human physiology pyq  body fluids and circulation
#
#    time_taken                                  combined
# 0   11.750000  2 90 105 15 107 12 human physiology (15)
# 1    9.933333    1 100 92 15 395 3 human physiology pyq

# %%
data.to_csv("../Data/final.csv")

# %% [markdown]
# # Vectorizing the Dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=40)
vectors = cv.fit_transform(data["combined"]).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.47809144, 0.63900965, 0.5976143 , 0.63245553,
#        0.31622777, 0.51639778, 0.23904572, 0.35856858, 0.25819889,
#        0.31622777, 0.28284271, 0.25819889, 0.47809144])

# %% [markdown]
# # Inferencing the Model

# %%
def recommend(title, score):
    idx = data[(data["title"] == title) & (data["score"] == score)].index[0]
    ans = sorted(list(enumerate(similarity[idx])), reverse=True, key=lambda x: x[1])[
        1:3
    ]
    results = set()
    for row in ans:
        results.add(data["topic"][row[0]].strip())
    return results


print(recommend("reproduction", 116))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 12
#       8         results.add(data["topic"][row[0]].strip())
#       9     return results
# ---> 12 print(recommend("reproduction", 116))
#
# Cell In[39], line 2, in recommend(title, score)
#       1 def recommend(title, score):
# ----> 2     idx = data[(data["title"] == title) & (data["score"] == score)].index[0]
#       3     ans = sorted(list(enumerate(similarity[idx])), reverse=True, key=lambda x: x[1])[
#       4         1:3
#       5     ]
#       6     results = set()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
# ...

# %% [markdown]
# # Saving the model
